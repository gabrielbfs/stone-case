# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from unicodedata import normalize
from datetime import datetime
import time

# %% [markdown]
# ---

# %% [markdown]
# # DATA CLEASING

# %%
cadastro = pd.read_csv('dados_case_ds2\\cadastrais.csv', parse_dates=True)
tpv = pd.read_csv('dados_case_ds2\\tpv-mensais-treinamento.csv')

# %% [markdown]
# - **comentátios:**
#
# Antes de iniciarmos um EDA, verifica-se a existência de id's duplicados na base, o que prejudicará futuras análises e cruzamento entre as bases. Assumindo id único para estabelicimento, pode-se inferir que houve uma atualização cadastral e, assim, definimos que o último dado corresponde a informação mais precisa.
#
# Contudo, ao verificarmos com os dados de TPV mensal, nota-se o início do relacionamento entre o estabelecimento e a Stone. Para os dados verificados, em geral esse relacionamento se iniciou na data mais antiga.
#
# Dessa forma, agrupa-se os dados para corrigir essas inconsistências. Outros casos podem surgir e serão discutidos futuramente, como por exemplo nos casos em que o assumimos o início do relacionamento com a primeira data, mas apenas existem dados de transações referente-se à segunda data.

# %%
duplicated_ids = cadastro['id'][cadastro['id'].duplicated()].values

# %%
cadastro[cadastro['id'].isin(duplicated_ids)].sort_values(['id', 'StoneCreatedDate']).head(4)
# Out:
#         id         StoneCreatedDate  StoneFirstTransactionDate     MCC  \
# 166484  21  2018-06-19 00:00:00.000                 20180626.0  5995.0
# 130681  21  2020-04-07 00:00:00.000                 20210102.0  5912.0
# 185808  29  2015-02-19 00:00:00.000                 20150221.0  7230.0
# 237704  29  2017-02-21 00:00:00.000                 20170223.0  7230.0
#
#            MacroClassificacao                                  segmento  \
# 166484                 Varejo                   Petshops e Veterinários
# 130681  Supermercado/Farmácia  Farmácias, Produtos de Saúde e Cosmética
# 185808               Serviços             Serviços de Beleza e Estética
# 237704               Serviços             Serviços de Beleza e Estética
#
#                  sub_segmento                             persona     porte  \
# 166484               Petshops  SMB - Pequeno Porte e Ticket Medio   10k-25k
# 130681  Drogarias e Farmácias  SMB - Pequeno Porte e Ticket Baixo   10k-25k
# 185808        Salão de Beleza    SMB - Medio Porte e Ticket Medio   25k-50k
# 237704        Salão de Beleza    SMB - Medio Porte e Ticket Medio  50k-100k
#
#         TPVEstimate tipo_documento Estado
# 166484       3000.0             PJ     BA
# 130681      10000.0             PJ     BA
# 185808          0.0             PJ     DF
# 237704      66000.0             PJ     DF

# %% [markdown]
# - **comentátios:**
#
# Exemplos de dados duplicados:

# %%
cadastro[cadastro['id'] == 83099].sort_values(['id', 'StoneCreatedDate'])
# Out:
#            id         StoneCreatedDate  StoneFirstTransactionDate     MCC  \
# 174299  83099  2017-12-11 00:00:00.000                 20171212.0  8043.0
# 123981  83099  2020-04-16 00:00:00.000                        0.0  8043.0
#
#        MacroClassificacao           segmento     sub_segmento  \
# 174299      Bens duráveis  Moda e Acessórios  Óticas e Óculos
# 123981      Bens duráveis  Moda e Acessórios  Óticas e Óculos
#
#                                 persona     porte  TPVEstimate tipo_documento  \
# 174299  SMB - Medio Porte e Ticket Alto  50k-100k      55200.0             PJ
# 123981  SMB - Medio Porte e Ticket Alto  50k-100k      10000.0             PJ
#
#        Estado
# 174299     RJ
# 123981     RJ

# %%
tpv[tpv['id'] == 83099]
# Out:
#             id  mes_referencia  TPV_mensal
# 1360035  83099        20171231    19190.76
# 1360036  83099        20180131    49969.58
# 1360037  83099        20180228    36602.90
# 1360038  83099        20180331    54438.33
# 1360039  83099        20180430    53653.76
# 1360040  83099        20180531    32458.55
# 1360041  83099        20180630    52948.00
# 1360042  83099        20180731    63286.10
# 1360043  83099        20180831    44664.80
# 1360044  83099        20180930    31218.50
# 1360045  83099        20181031    52576.00
# 1360046  83099        20181130    32632.90
# 1360047  83099        20181231    44214.89
# 1360048  83099        20190131    47706.90
# 1360049  83099        20190228    44830.60
# 1360050  83099        20190331    55368.50
# 1360051  83099        20190430    46000.20
# 1360052  83099        20190531    59957.20
# 1360053  83099        20190630    32028.00
# 1360054  83099        20190731    53012.02
# 1360055  83099        20190831    52582.80
# 1360056  83099        20190930    43965.40
# 1360057  83099        20191031    57976.00
# 1360058  83099        20191130    55189.00
# 1360059  83099        20191231    61993.80
# 1360060  83099        20200131    53925.00
# 1360061  83099        20200229    52043.70
# 1360062  83099        20200331    32916.00
# 1360063  83099        20200430     5804.00
# 1360064  83099        20200531    21123.73
# 1360065  83099        20200630    45800.60
# 1360066  83099        20200731    62023.60

# %%
cadastro[cadastro['id'] == 178808].sort_values(['id', 'StoneCreatedDate'])
# Out:
#             id         StoneCreatedDate  StoneFirstTransactionDate     MCC  \
# 93886   178808  2015-01-27 00:00:00.000                 20150305.0  5499.0
# 103844  178808  2020-01-28 00:00:00.000                 20200204.0  5499.0
#
#        MacroClassificacao               segmento           sub_segmento  \
# 93886         Alimentação  Alimentação e Bebidas  Comércio de Alimentos
# 103844        Alimentação  Alimentação e Bebidas  Comércio de Alimentos
#
#        persona    porte  TPVEstimate tipo_documento Estado
# 93886    Outro  2.5k-5k          0.0             PJ     MG
# 103844   Outro  2.5k-5k          0.0             PJ     MG

# %%
tpv[tpv['id'] == 178808]
# Out:
#              id  mes_referencia  TPV_mensal
# 2616135  178808        20200229      773.65
# 2616136  178808        20200331     2476.91
# 2616137  178808        20200430     5864.95
# 2616138  178808        20200531     6457.70
# 2616139  178808        20200630     6874.45
# 2616140  178808        20200731     5335.04

# %% [markdown]
# ---

# %%
cadastro = cadastro.sort_values(['id', 'StoneCreatedDate', 'StoneFirstTransactionDate'])
cadastro_df1 = cadastro[['id', 'StoneCreatedDate', 'StoneFirstTransactionDate']]
cadastro_df2 = cadastro.drop(['StoneCreatedDate', 'StoneFirstTransactionDate'], axis='columns')

# %%
cadastro_df1 = cadastro_df1.drop_duplicates(subset=['id'], keep='first')
cadastro_df2 = cadastro_df2.drop_duplicates(subset=['id'], keep='last')

# %%
cadastro_proc = cadastro_df1.merge(cadastro_df2, on='id', how='inner')
cadastro_proc = cadastro_proc[cadastro_proc['id'].isin(tpv['id'].drop_duplicates())]

# %%
cadastro_proc = cadastro_proc[cadastro_proc['id'].isin(tpv['id'].drop_duplicates())]

# %%
cadastro_proc['id'] = cadastro_proc['id'].astype(int)
cadastro_proc = cadastro_proc.set_index('id')

# %%
cadastro_proc['StoneCreatedDate'] = pd.to_datetime(cadastro_proc['StoneCreatedDate'], yearfirst=True, dayfirst=False)
cadastro_proc['StoneFirstTransactionDate'] = cadastro_proc['StoneFirstTransactionDate'].astype(int)

# %%
cadastro_proc.loc[cadastro_proc['StoneFirstTransactionDate'] != 0., 'StoneFirstTransactionDate'] = pd.to_datetime(cadastro_proc.loc[cadastro_proc['StoneFirstTransactionDate'] != 0., 'StoneFirstTransactionDate'], format='%Y%m%d')
cadastro_proc.loc[cadastro_proc['StoneFirstTransactionDate'] == 0., 'StoneFirstTransactionDate'] = pd.to_datetime(cadastro_proc.loc[cadastro_proc['StoneFirstTransactionDate'] == 0., 'StoneCreatedDate'], yearfirst=True, dayfirst=False)

# %%
cadastro_proc['StoneFirstTransactionDate'] = pd.to_datetime(cadastro_proc['StoneFirstTransactionDate'], yearfirst=True, dayfirst=False)

# %% [markdown]
# - **comentátios:**
#
# Seguindo com a análise dos dados, verifica-se a necessidade de redefinir os estabelecimentos que foram atribuídos como MCC (Merchant Category Code) igual a zero. Nesse caso, iremos recuperar os dados definidos à priori. Nesse caso, assumi-se erro no preenchimento dos dados.

# %%
cadastro_proc[cadastro_proc['MCC'].astype(int) == 0]
# Out:
#        StoneCreatedDate StoneFirstTransactionDate  MCC MacroClassificacao  \
# id
# 295          2015-11-11                2015-12-02  0.0                NaN
# 1405         2019-01-08                2019-02-18  0.0                NaN
# 1794         2018-09-13                2018-09-13  0.0                NaN
# 1900         2019-07-01                2019-08-07  0.0                NaN
# 2087         2018-12-17                2018-12-21  0.0                NaN
# ...                 ...                       ...  ...                ...
# 201999       2017-05-08                2017-05-09  0.0                NaN
# 202613       2016-06-23                2016-06-25  0.0                NaN
# 205297       2016-11-11                2016-11-23  0.0                NaN
# 205469       2018-08-09                2018-08-10  0.0                NaN
# 205963       2017-03-10                2017-03-24  0.0                NaN
#
#        segmento sub_segmento             persona     porte  TPVEstimate  \
# id
# 295         NaN          NaN  Micro Empreendedor    0-2.5k          0.0
# 1405        NaN          NaN  Micro Empreendedor    0-2.5k          0.0
# 1794        NaN          NaN  Micro Empreendedor    0-2.5k          0.0
# 1900        NaN          NaN               Outro  50k-100k          0.0
# 2087        NaN          NaN  Micro Empreendedor    0-2.5k          0.0
# ...         ...          ...                 ...       ...          ...
# 201999      NaN          NaN               Outro    0-2.5k          0.0
# 202613      NaN          NaN  Micro Empreendedor    0-2.5k          0.0
# 205297      NaN          NaN  Micro Empreendedor    0-2.5k          0.0
# 205469      NaN          NaN  Micro Empreendedor    0-2.5k          0.0
# 205963      NaN          NaN  Micro Empreendedor    0-2.5k          0.0
#
#        tipo_documento Estado
# id
# 295                PJ    NaN
# 1405               PJ    NaN
# 1794               PJ    NaN
# 1900               PJ    NaN
# 2087               PJ    NaN
# ...               ...    ...
# 201999             PJ    NaN
# 202613             PJ    NaN
# 205297             PJ    NaN
# 205469             PJ    NaN
# 205963             PJ    NaN
#
# [334 rows x 11 columns]

# %%
cadastro.loc[cadastro['id'] == 202613]
# Out:
#             id         StoneCreatedDate  StoneFirstTransactionDate     MCC  \
# 66951   202613  2016-06-23 00:00:00.000                 20160625.0  5651.0
# 94766   202613  2016-06-23 00:00:00.000                 20170811.0  5651.0
# 233660  202613  2018-03-08 00:00:00.000                        0.0     0.0
#
#        MacroClassificacao           segmento sub_segmento  \
# 66951              Varejo  Moda e Acessórios    Vestuário
# 94766              Varejo  Moda e Acessórios    Vestuário
# 233660                NaN                NaN          NaN
#
#                                  persona    porte  TPVEstimate tipo_documento  \
# 66951   SMB - Medio Porte e Ticket Medio  25k-50k          0.0             PJ
# 94766   SMB - Medio Porte e Ticket Medio  25k-50k          1.0             PJ
# 233660                Micro Empreendedor   0-2.5k          0.0             PJ
#
#        Estado
# 66951      RS
# 94766      RS
# 233660    NaN

# %%
cadastro_proc.loc[[202613]]
# Out:
#        StoneCreatedDate StoneFirstTransactionDate  MCC MacroClassificacao  \
# id
# 202613       2016-06-23                2016-06-25  0.0                NaN
#
#        segmento sub_segmento             persona   porte  TPVEstimate  \
# id
# 202613      NaN          NaN  Micro Empreendedor  0-2.5k          0.0
#
#        tipo_documento Estado
# id
# 202613             PJ    NaN

# %%
tpv[tpv['id'] == 202613]
# Out:
#              id  mes_referencia  TPV_mensal
# 3007957  202613        20170731    47825.37
# 3007958  202613        20170831    56675.67
# 3007959  202613        20170930    46128.42
# 3007960  202613        20171031    49422.26
# 3007961  202613        20171130    46588.80
# 3007962  202613        20171231    69155.55
# 3007963  202613        20180131    45996.89
# 3007964  202613        20180228    42857.66
# 3007965  202613        20180331    49910.95
# 3007966  202613        20180430    36444.21
# 3007967  202613        20180531    42838.59
# 3007968  202613        20180630    43080.63
# 3007969  202613        20180731    56535.16
# 3007970  202613        20180831    45943.10
# 3007971  202613        20180930    44494.74
# 3007972  202613        20181031    41269.27
# 3007973  202613        20181130    46694.98
# 3007974  202613        20181231    61174.68
# 3007975  202613        20190131    41328.76
# 3007976  202613        20190228    61048.85
# 3007977  202613        20190331    60534.70
# 3007978  202613        20190430    68366.68
# 3007979  202613        20190531    57594.57
# 3007980  202613        20190630    57494.80
# 3007981  202613        20190731    61996.79
# 3007982  202613        20190831    94918.23
# 3007983  202613        20190930    51794.85
# 3007984  202613        20191031    56762.27
# 3007985  202613        20191130    68990.78
# 3007986  202613        20191231    89788.12
# 3007987  202613        20200131    50459.08
# 3007988  202613        20200229    52935.84
# 3007989  202613        20200331    43283.09
# 3007990  202613        20200430     7150.73
# 3007991  202613        20200531    42528.76
# 3007992  202613        20200630    47097.78
# 3007993  202613        20200731    45950.49

# %%
cadastro_proc.loc[(cadastro_proc['MCC'].astype(int) == 0)&(cadastro_proc['StoneFirstTransactionDate'] != 0.), 'StoneFirstTransactionDate']
# Out:
# id
# 295      2015-12-02
# 1405     2019-02-18
# 1794     2018-09-13
# 1900     2019-08-07
# 2087     2018-12-21
#             ...
# 201999   2017-05-09
# 202613   2016-06-25
# 205297   2016-11-23
# 205469   2018-08-10
# 205963   2017-03-24
# Name: StoneFirstTransactionDate, Length: 334, dtype: datetime64[ns]

# %%
cadastro_mcc_zero = cadastro[cadastro['id'].isin(cadastro_proc.loc[cadastro_proc['MCC'].astype(int) == 0].index)].sort_values(['id', 'StoneCreatedDate', 'StoneFirstTransactionDate', 'MCC']).drop_duplicates(subset=['id'], keep='first').set_index('id')
cadastro_mcc_zero.loc[cadastro_mcc_zero['StoneFirstTransactionDate'] != 0., 'StoneFirstTransactionDate'] = pd.to_datetime(cadastro_mcc_zero.loc[cadastro_mcc_zero['StoneFirstTransactionDate'] != 0., 'StoneFirstTransactionDate'].astype(int), format='%Y%m%d')
cadastro_proc.loc[cadastro_proc['MCC'].astype(int) == 0] = cadastro_mcc_zero
cadastro_proc.loc[(cadastro_proc['MCC'].astype(int) == 0)&(cadastro_proc['StoneFirstTransactionDate'] != 0.), 'StoneFirstTransactionDate'] = pd.to_datetime(cadastro_proc.loc[(cadastro_proc['MCC'].astype(int) == 0)&(cadastro_proc['StoneFirstTransactionDate'] != 0.), 'StoneFirstTransactionDate'], format='%Y%m%d')

# %%
id_nan = cadastro_proc[cadastro_proc['StoneFirstTransactionDate'] == 0].index
cadastro_id_nan = cadastro.set_index('id').loc[id_nan]
cadastro_id_nan['NaN qtd'] = np.sum(cadastro_id_nan.replace({0.0:np.nan}).isna(), axis='columns')
cadastro_id_nan = cadastro_id_nan.reset_index().sort_values(['NaN qtd']).drop_duplicates(subset='id', keep='first').set_index('id').sort_index().drop('NaN qtd', axis='columns')
cadastro_id_nan.loc[cadastro_id_nan['StoneFirstTransactionDate'] != 0., 'StoneFirstTransactionDate'] = pd.to_datetime(cadastro_id_nan.loc[cadastro_id_nan['StoneFirstTransactionDate'] != 0., 'StoneFirstTransactionDate'].astype(int), format='%Y%m%d')
cadastro_proc[cadastro_proc['StoneFirstTransactionDate'] == 0.] = cadastro_id_nan

# %%
cadastro_proc.loc[cadastro_proc['StoneFirstTransactionDate'] == 0, 'StoneFirstTransactionDate'] = pd.to_datetime(cadastro_proc.loc[cadastro_proc['StoneFirstTransactionDate'] == 0, 'StoneCreatedDate'])
cadastro_proc['StoneCreatedDate'] = pd.to_datetime(cadastro_proc['StoneCreatedDate'], yearfirst=True, dayfirst=False)

# %%
cadastro_proc['StoneFirstTransactionDate'] = pd.to_datetime(cadastro_proc['StoneFirstTransactionDate'])

# %%
cadastro_proc
# Out:
#        StoneCreatedDate StoneFirstTransactionDate     MCC  \
# id
# 1            2018-12-12                2018-12-13  5942.0
# 2            2020-04-13                2020-04-14  5231.0
# 3            2019-05-31                2019-06-15  5411.0
# 4            2017-09-29                2017-10-02  4215.0
# 5            2019-01-31                2019-01-31  5698.0
# ...                 ...                       ...     ...
# 206326       2019-05-16                2019-05-20  7997.0
# 206327       2020-01-21                2020-01-22  5331.0
# 206328       2019-07-15                2019-07-17  8021.0
# 206329       2019-12-18                2019-12-26  5651.0
# 206330       2020-04-24                2020-04-29  5411.0
#
#            MacroClassificacao                                  segmento  \
# id
# 1                      Varejo  Livrarias, Papelarias, Gráficas e Bancas
# 2               Bens duráveis                   Materiais de Construção
# 3       Supermercado/Farmácia                             Supermercados
# 4                    Serviços                    Logística e Mobilidade
# 5                    Serviços             Serviços de Beleza e Estética
# ...                       ...                                       ...
# 206326   Serviços recorrentes                         Esporte e Fitness
# 206327          Bens duráveis                     Lojas de Departamento
# 206328               Serviços              Serviços de Saúde e Clínicas
# 206329                 Varejo                         Moda e Acessórios
# 206330  Supermercado/Farmácia                             Supermercados
#
#                    sub_segmento                             persona     porte  \
# id
# 1        Livrarias e Papelarias    SMB - Medio Porte e Ticket Medio  50k-100k
# 2       Materiais de Construção   SMB - Pequeno Porte e Ticket Alto   10k-25k
# 3                 Supermercados                Pequeno Empreendedor   2.5k-5k
# 4            Delivery e Entrega    SMB - Medio Porte e Ticket Medio   25k-50k
# 5               Salão de Beleza  SMB - Pequeno Porte e Ticket Medio    5k-10k
# ...                         ...                                 ...       ...
# 206326       Academias e Clubes   SMB - Pequeno Porte e Ticket Alto   10k-25k
# 206327    Lojas de Departamento   SMB - Pequeno Porte e Ticket Alto   10k-25k
# 206328              Odontologia                Pequeno Empreendedor   2.5k-5k
# 206329                Vestuário    SMB - Medio Porte e Ticket Medio  50k-100k
# 206330            Supermercados                               Outro   10k-25k
#
#         TPVEstimate tipo_documento Estado
# id
# 1           71000.0             PJ     MG
# 2           10001.0             PF     RS
# 3            3000.0             PF     RJ
# 4           25000.0             PJ     RJ
# 5            6000.0             PF     PE
# ...             ...            ...    ...
# 206326       4000.0             PF     SP
# 206327      20000.0             PJ     PE
# 206328       2000.0             PF     RJ
# 206329      60000.0             PJ     MG
# 206330       5000.0             PF     AM
#
# [205833 rows x 11 columns]

# %%
estados = {'Acre':'AC',
            'Alagoas':'AL',
            'Amapa':'AP',
            'Amazonas':'AM',
            'Bahia':'BA',
            'Ceara':'CE',
            'Espirito Santo':'ES',
            'Goias':'GO',
            'Maranhao':'MA',
            'Mato Grosso':'MT',
            'Mato Grosso do Sul':'MS',
            'Minas Gerais':'MG',
            'Para':'PA',
            'Paraiba':'PB',
            'Parana':'PR',
            'Pernambuco':'PE',
            'Piaui':'PI',
            'Rio de Janeiro':'RJ',
            'Rio Grande do Norte':'RN',
            'Rio Grande do Sul':'RS',
            'Rondonia':'RO',
            'Roraima':'RR',
            'Santa Catarina':'SC',
            'Sao Paulo':'SP',
            'Sergipe':'SE',
            'Tocantins':'TO',
            'Distrito Federal':'DF', 
            'NAN':'BR'}

# %%
cadastro_proc['MCC'] = cadastro_proc['MCC'].astype(int).astype(str).str.zfill(4)
cadastro_proc['MacroClassificacao'] = cadastro_proc['MacroClassificacao'].fillna('Outro')
cadastro_proc['segmento'] = cadastro_proc['segmento'].fillna('Outro')
cadastro_proc['sub_segmento'] = cadastro_proc['sub_segmento'].fillna('Outro')
cadastro_proc['persona'] = cadastro_proc['persona'].fillna('Outro')
cadastro_proc['porte'] = cadastro_proc['porte'].fillna('Outro')
cadastro_proc['TPVEstimate'] = cadastro_proc['TPVEstimate'].astype(int).fillna(0)
cadastro_proc['tipo_documento'] = cadastro_proc['tipo_documento'].fillna('Outro')
cadastro_proc['Estado'] = cadastro_proc['Estado'].apply(lambda x: normalize('NFKD', str(x)).encode('ASCII', 'ignore').decode('ASCII'))
cadastro_proc['Estado'] = cadastro_proc['Estado'].replace(estados).str.upper()

# %%
assert cadastro_proc.isna().sum().sum() == 0

# %%
cadastro_proc.to_csv('preprocessed data//cadastrais_preprocessed.csv')

# %% [markdown]
# ---

# %%
tpv['mes_referencia'] = pd.to_datetime(tpv['mes_referencia'], format='%Y%m%d')

# %%
tpv.to_csv('preprocessed data//tpv_mensal_preprocessed.csv', index=False)

# %% [markdown]
# ---
